# %%
import pandas as pd

# %%
df = pd.read_csv('daTA.csv')

# %%
df.head()
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0     ritz  2014           3.35           5.59       27000    Petrol
# 1      sx4  2013           4.75           9.54       43000    Diesel
# 2     ciaz  2017           7.25           9.85        6900    Petrol
# 3  wagon r  2011           2.85           4.15        5200    Petrol
# 4    swift  2014           4.60           6.87       42450    Diesel
#
#   Seller_Type Transmission  Owner
# 0      Dealer       Manual      0
# 1      Dealer       Manual      0
# 2      Dealer       Manual      0
# 3      Dealer       Manual      0
# 4      Dealer       Manual      0

# %%
df.columns
# Out:
# Index(['Car_Name', 'Year', 'Selling_Price', 'Present_Price', 'Kms_Driven',
#        'Fuel_Type', 'Seller_Type', 'Transmission', 'Owner'],
#       dtype='object')

# %%
df.shape
# Out:
# (301, 9)

# %%
df.dtypes
# Out:
# Car_Name          object
# Year               int64
# Selling_Price    float64
# Present_Price    float64
# Kms_Driven         int64
# Fuel_Type         object
# Seller_Type       object
# Transmission      object
# Owner              int64
# dtype: object

# %%
def value_counts():
    for i in df.columns:
        print(df[i].value_counts())
value_counts()
# Out:
# city                        26
# corolla altis               16
# verna                       14
# fortuner                    11
# brio                        10
#                             ..
# Honda CB Trigger             1
# Yamaha FZ S                  1
# Bajaj Pulsar 135 LS          1
# Activa 4g                    1
# Bajaj Avenger Street 220     1
# Name: Car_Name, Length: 98, dtype: int64
# 2015    61
# 2016    50
# 2014    38
# 2017    35
# 2013    33
# 2012    23
# 2011    19
# 2010    15
# 2008     7
# 2009     6
# 2006     4
# 2005     4
# 2003     2
# 2007     2
# 2018     1
# 2004     1
# Name: Year, dtype: int64
# 0.45     8
# 0.60     8
# 5.25     7
# 4.50     7
# 0.20     6
#         ..
# 3.80     1
# 3.45     1
# 5.90     1
# 35.00    1
# 11.50    1
# Name: Selling_Price, Length: 156, dtype: int64
# 9.40     15
# 13.60    13
# 5.70      8
# 4.43      7
# 1.47      7
#          ..
# 18.54     1
# 7.27      1
# 15.04     1
# 10.21     1
# 12.50     1
# Name: Present_Price, Length: 147, dtype: int64
# 45000    9
# 15000    9
# 40000    5
# 35000    5
# 50000    5
#         ..
# 1400     1
# 1200     1
# 4100     1
# 21700    1
# 5464     1
# Name: Kms_Driven, Length: 206, dtype: int64
# Petrol    239
# Diesel     60
# CNG         2
# Name: Fuel_Type, dtype: int64
# Dealer        195
# Individual    106
# Name: Seller_Type, dtype: int64
# Manual       261
# Automatic     40
# Name: Transmission, dtype: int64
# 0    290
# 1     10
# 3      1
# Name: Owner, dtype: int64

# %%
df.duplicated().sum()
# Out:
# 2

# %%
df.drop(columns=['Fuel_Type'],axis=1,inplace=True)

# %%
df
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Seller_Type  \
# 0       ritz  2014           3.35           5.59       27000      Dealer
# 1        sx4  2013           4.75           9.54       43000      Dealer
# 2       ciaz  2017           7.25           9.85        6900      Dealer
# 3    wagon r  2011           2.85           4.15        5200      Dealer
# 4      swift  2014           4.60           6.87       42450      Dealer
# ..       ...   ...            ...            ...         ...         ...
# 296     city  2016           9.50          11.60       33988      Dealer
# 297     brio  2015           4.00           5.90       60000      Dealer
# 298     city  2009           3.35          11.00       87934      Dealer
# 299     city  2017          11.50          12.50        9000      Dealer
# 300     brio  2016           5.30           5.90        5464      Dealer
#
#     Transmission  Owner
# 0         Manual      0
# 1         Manual      0
# 2         Manual      0
# 3         Manual      0
# 4         Manual      0
# ..           ...    ...
# 296       Manual      0
# 297       Manual      0
# 298       Manual      0
# 299       Manual      0
# 300       Manual      0
#
# [301 rows x 8 columns]

# %%
df.columns
# Out:
# Index(['Car_Name', 'Year', 'Selling_Price', 'Present_Price', 'Kms_Driven',
#        'Seller_Type', 'Transmission', 'Owner'],
#       dtype='object')

# %%
numerical_feat =[]
categorical_feat=[]
for i in df.columns:
    if (df[i].dtypes !=object):
        numerical_feat.append(i)
    else:
        categorical_feat.append(i)

# %%
df.dtypes
# Out:
# Car_Name          object
# Year               int64
# Selling_Price    float64
# Present_Price    float64
# Kms_Driven         int64
# Seller_Type       object
# Transmission      object
# Owner              int64
# dtype: object

# %%
numerical_feat
# Out:
# ['Year', 'Selling_Price', 'Present_Price', 'Kms_Driven', 'Owner']

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
len(categorical_feat)
# Out:
# 3

# %%
categorical_feat
# Out:
# ['Car_Name', 'Seller_Type', 'Transmission']

# %%
numerical_feat
# Out:
# ['Year', 'Selling_Price', 'Present_Price', 'Kms_Driven', 'Owner']

# %%
len(numerical_feat)
# Out:
# 5

# %%
df.corr()
# Out:
# <ipython-input-22-2f6f6606aa2c>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#                    Year  Selling_Price  Present_Price  Kms_Driven     Owner
# Year           1.000000       0.236141      -0.047584   -0.524342 -0.182104
# Selling_Price  0.236141       1.000000       0.878983    0.029187 -0.088344
# Present_Price -0.047584       0.878983       1.000000    0.203647  0.008057
# Kms_Driven    -0.524342       0.029187       0.203647    1.000000  0.089216
# Owner         -0.182104      -0.088344       0.008057    0.089216  1.000000

# %%
plt.figure(figsize = (16,5))
ax = sns.heatmap(df.corr(), annot=True, linewidths=.1)
# Out:
# <ipython-input-23-35ff1cf5cfc2>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   ax = sns.heatmap(df.corr(), annot=True, linewidths=.1)

# %%
df[categorical_feat].head()
# Out:
#   Car_Name Seller_Type Transmission
# 0     ritz      Dealer       Manual
# 1      sx4      Dealer       Manual
# 2     ciaz      Dealer       Manual
# 3  wagon r      Dealer       Manual
# 4    swift      Dealer       Manual

# %%
for feature in categorical_feat:
    df.groupby(feature)['Present_Price'].median().plot.bar()
    plt.xlabel(feature)
    plt.ylabel('Present_Price')
    plt.title(feature)
    plt.figure(figsize=(10,10))
    plt.show()

# %%
for feature in numerical_feat:
    df.groupby(feature)['Present_Price'].mean().plot()
    plt.xlabel(feature)
    plt.ylabel('Present_Price')
    plt.title(feature)
    plt.show()

# %%
discrete_feature=[feature for feature in numerical_feat if len(df[feature].unique())<25 and feature not in ['Id']]
print("Discrete Variables Count: {}".format(len(discrete_feature)))
# Out:
# Discrete Variables Count: 2

# %%
discrete_feature
# Out:
# ['Year', 'Owner']

# %%
df[discrete_feature].head()
# Out:
#    Year  Owner
# 0  2014      0
# 1  2013      0
# 2  2017      0
# 3  2011      0
# 4  2014      0

# %%
for feature in discrete_feature:
    df.groupby(feature)['Present_Price'].mean().plot.bar()
    plt.xlabel(feature)
    plt.ylabel('Present_Price')
    plt.title(feature)
    plt.show()

# %%
continuous_feature=[feature for feature in numerical_feat if feature not in discrete_feature]
continuous_feature
# Out:
# ['Selling_Price', 'Present_Price', 'Kms_Driven']

# %%
for feature in continuous_feature:
    df[feature].hist(bins=25)
    plt.xlabel(feature)
    plt.ylabel("Count")
    plt.title(feature)
    plt.show()

# %%
import numpy as np

# %%
for feature in continuous_feature:
    if 0 in df[feature].unique():
        pass
    else:
        df[feature]=np.log(df[feature])
        df['Present_Price']=np.log(df['Present_Price'])
        plt.scatter(df[feature],df['Present_Price'])
        plt.xlabel(feature)
        plt.ylabel('Present_Price')
        plt.title(feature)
        plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/pandas/core/arraylike.py:402: RuntimeWarning: invalid value encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
for feature in continuous_feature:
    if 0 in df[feature].unique():
        pass
    else:
        df[feature]=np.log(df[feature])
        df.boxplot(column=feature)
        plt.ylabel(feature)
        plt.title(feature)
        plt.show()

# %%
x=df[numerical_feat]
x
# Out:
#      Year  Selling_Price  Present_Price  Kms_Driven  Owner
# 0    2014       1.208960            NaN    2.322740      0
# 1    2013       1.558145            NaN    2.367338      0
# 2    2017       1.981001            NaN    2.179205      0
# 3    2011       1.047319            NaN    2.146681      0
# 4    2014       1.526056            NaN    2.366131      0
# ..    ...            ...            ...         ...    ...
# 296  2016       2.251292            NaN    2.345047      0
# 297  2015       1.386294            NaN    2.398086      0
# 298  2009       1.208960            NaN    2.432239      0
# 299  2017       2.442347            NaN    2.208822      0
# 300  2016       1.667707            NaN    2.152452      0
#
# [301 rows x 5 columns]

# %%
y = df.iloc[:,-1:]
y
# Out:
#      Owner
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
# ..     ...
# 296      0
# 297      0
# 298      0
# 299      0
# 300      0
#
# [301 rows x 1 columns]

# %%
from sklearn.decomposition import PCA
feat = PCA(n_components=5)
feat
# Out:
# PCA(n_components=5)

# %%
feat.get_params()
# Out:
# {'copy': True,
#  'iterated_power': 'auto',
#  'n_components': 5,
#  'n_oversamples': 10,
#  'power_iteration_normalizer': 'auto',
#  'random_state': None,
#  'svd_solver': 'auto',
#  'tol': 0.0,
#  'whiten': False}

# %%
df['Transmission']=np.where(df['Transmission']=="Manual",1,0)
df.head()
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Seller_Type  \
# 0     ritz  2014       1.208960            NaN    2.322740      Dealer
# 1      sx4  2013       1.558145            NaN    2.367338      Dealer
# 2     ciaz  2017       1.981001            NaN    2.179205      Dealer
# 3  wagon r  2011       1.047319            NaN    2.146681      Dealer
# 4    swift  2014       1.526056            NaN    2.366131      Dealer
#
#    Transmission  Owner
# 0             1      0
# 1             1      0
# 2             1      0
# 3             1      0
# 4             1      0
